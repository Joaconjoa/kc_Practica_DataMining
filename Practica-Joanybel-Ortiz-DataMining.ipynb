# %% [markdown]
# Vasmos a cargar el dataset de AirBnB descargado de [aquí](https://public.opendatasoft.com/explore/dataset/airbnb-listings/export/?disjunctive.host_verifications&disjunctive.amenities&disjunctive.features&q=Madrid&dataChart=...%3D&location=16,41.38377,2.15774&basemap=jawg.streets)
#
# ![](descargar.png)

# %%
airbnb<-read.csv('airbnb-listings.csv',sep = ';')
options(repr.plot.height=4,repr.plot.width=6,repr.plot.res =300)

# %% [markdown]
# Vamos a quedarnos con las columnas de mayor interés:
#
# 'City','Room.Type','Neighbourhood','Accommodates','Bathrooms','Bedrooms','Beds','Price','Square.Feet','Guests.Included','Extra.People','Review.Scores.Rating','Latitude', 'Longitude'

# %%
airbnb = airbnb [, c('City','Room.Type','Neighbourhood','Accommodates','Bathrooms','Bedrooms','Beds','Price','Square.Feet','Guests.Included','Extra.People','Review.Scores.Rating','Latitude', 'Longitude')]
head(airbnb)
# Out:
#   City   Room.Type       Neighbourhood Accommodates Bathrooms Bedrooms Beds
# 1 Madrid Entire home/apt               2            1.0       0        1
# 2 Madrid Entire home/apt               4            1.0       1        2
# 3 Madrid Entire home/apt               4            1.5       1        2
# 4 Madrid Entire home/apt Embajadores   2            1.0       1        2
# 5 Madrid Entire home/apt Embajadores   5            1.0       2        4
# 6 Madrid Entire home/apt La Latina     4            1.0       1        2
#   Price Square.Feet Guests.Included Extra.People Review.Scores.Rating Latitude
# 1 50    NA          2               15           96                   40.40745
# 2 50    NA          2               25           81                   40.40832
# 3 77    NA          1                0           89                   40.41372
# 4 50    NA          1               20           93                   40.41126
# 5 95    NA          4                0           97                   40.41256
# 6 69    NA          2               18           91                   40.40791
#   Longitude
# 1 -3.707995
# 2 -3.705006
# 3 -3.706823
# 4 -3.697305
# 5 -3.701155
# 6 -3.705095

# %% [markdown]
# Nos quedarmos solo con las entradas de Madrid para Room.Type=="Entire home/apt" y cuyo barrio (Neighbourhood) no está vacio ''
# Podemos eliminar las siguientes columnas que ya no son necesarias:
# "Room.Type",'City'
#
# Llama a nuevo dataframe df_madrid.

# %%
df_madrid <- airbnb[airbnb$City=="Madrid" & airbnb$Room.Type=="Entire home/apt" & airbnb$Neighbourhood != "",]
df_madrid$Room.Type <- NULL
df_madrid$City <- NULL
df_madrid
# Out:
#       Neighbourhood Accommodates Bathrooms Bedrooms Beds Price Square.Feet
# 4     Embajadores    2           1         1         2    50    NA
# 5     Embajadores    5           1         2         4    95    NA
# 6     La Latina      4           1         1         2    69    NA
# 9     Embajadores    4           1         1         2    57    NA
# 10    La Latina      2           1         1         1    59    NA
# 15    La Latina     14           2         3        14   120    NA
# 21    La Latina      2           1         1         1    89    NA
# 22    Palacio        5           3         3         3   192    NA
# 23    La Latina      4           1         1         1   100    NA
# 26    Palacio        5           2         2         2   100    NA
# 28    La Latina      4           2         2         3   160    NA
# 29    Palacio        4           1         1         2    80    NA
# 30    Palacio        3           1         1         1    68    NA
# 31    Palacio        6           1         2         2    80    NA
# 35    Embajadores    3           1         1         1    50    NA
# 38    Embajadores    3           1         2         2    50    NA
# 42    La Latina      3           1         1         2    75    NA
# 44    Embajadores    5           1         1         3    75    NA
# 45    La Latina      3           1         1         2    55    NA
# 46    Embajadores    3           1         0         2    65    NA
# 48    Palacio        4           1         1         3    60    NA
# 51    La Latina      6           2         2         2    72   592
# 52    Palacio        2           1         0         1    60    NA
# 55    Palacio        4           1         1         2    98    NA
# 60    Palacio        4           1         1         2    63    NA
# 61    La Latina      4           1         1         2    80    NA
# 63    La Latina      3           1         1         2    60    NA
# 64    Palacio        3           1         1         1    40    NA
# 66    La Latina     12           2         5         8   300    NA
# 67    La Latina      2           1         1         1    65    NA
# ⋮     ⋮             ⋮            ⋮         ⋮        ⋮    ⋮     ⋮
# 14709 La Latina      2           1.0       1        1     41    NA
# 14713 Embajadores    2           1.0       1        1     47    NA
# 14715 Embajadores    6           2.0       3        5    120    NA
# 14716 Embajadores    3           1.0       1        2     50    NA
# 14717 Embajadores    4           1.5       2        2     71    NA
# 14718 La Latina      2           1.0       1        1     75   431
# 14723 Embajadores    2           1.0       0        2     41    NA
# 14725 La Latina      4           1.0       1        1     69    NA
# 14731 La Latina      4           1.0       2        3     95    NA
# 14734 Cortes         2           1.0       0        2     89    NA
# 14736 Cortes         4           1.0       1        2     49    NA
# 14737 Cortes         4           1.0       1        2     65    NA
# 14738 Cortes         5           2.0       2        3    145    NA
# 14739 Cortes         4           1.0       2        3     58    NA
# 14743 Justicia       2           1.0       1        1     79    NA
# 14744 Justicia       4           1.0       2        2     69    NA
# 14745 Justicia       4           1.0       2        2     50    NA
# 14746 Justicia      12           3.0       4        8    250    NA
# 14748 Justicia       4           1.0       0        2     65    NA
# 14750 Justicia       2           1.0       0        1     74    NA
# 14751 Justicia       2           1.0       1        1     50    NA
# 14753 Cortes         4           1.0       1        2     65    NA
# 14754 Cortes         4           1.0       1        1     80    NA
# 14758 Cortes         4           1.0       0        2     65    NA
# 14759 Cortes         9           2.0       2        6     80    NA
# 14760 Cortes         3           1.0       1        3    200    NA
# 14761 Embajadores    4           1.0       1        2    150    NA
# 14763 Cortes         4           2.0       2        2    127    NA
# 14764 Centro         4           1.0       1        1     70    NA
# 14767 Cortes         4           1.0       1        3     80    NA
#       Guests.Included Extra.People Review.Scores.Rating Latitude Longitude
# 4     1               20            93                  40.41126 -3.697305
# 5     4                0            97                  40.41256 -3.701155
# 6     2               18            91                  40.40791 -3.705095
# 9     2                8            98                  40.41162 -3.703281
# 10    1                0            95                  40.40734 -3.707019
# 15    2               18            92                  40.40908 -3.704744
# 21    1               10            98                  40.41007 -3.710624
# 22    2               12            80                  40.42017 -3.712629
# 23    2               12            NA                  40.40990 -3.710948
# 26    2               15            95                  40.42156 -3.709848
# 28    1                0            93                  40.41173 -3.712662
# 29    2                0            88                  40.42099 -3.710402
# 30    2                5            83                  40.41203 -3.715779
# 31    4               25            95                  40.41512 -3.710294
# 35    2               20            89                  40.41205 -3.701022
# 38    1               10            93                  40.40581 -3.700252
# 42    2               12           100                  40.41087 -3.706967
# 44    2               15            95                  40.41180 -3.703943
# 45    2                8            NA                  40.40893 -3.704979
# 46    2               15           100                  40.41268 -3.701247
# 48    2               15            75                  40.42141 -3.707650
# 51    2               20            90                  40.41206 -3.709149
# 52    1                0            82                  40.41628 -3.710189
# 55    2               20            88                  40.41968 -3.710745
# 60    2               10            95                  40.42248 -3.710156
# 61    2               20            99                  40.41322 -3.711935
# 63    2               10            98                  40.41248 -3.708995
# 64    2               10            89                  40.41106 -3.716840
# 66    7               20            93                  40.41242 -3.707873
# 67    1                0           100                  40.40961 -3.710649
# ⋮     ⋮               ⋮            ⋮                    ⋮        ⋮
# 14709 1                0            85                  40.40975 -3.708745
# 14713 1                0            NA                  40.40650 -3.700280
# 14715 2               18            89                  40.41099 -3.698289
# 14716 1                0            87                  40.40859 -3.699698
# 14717 2               20            97                  40.40671 -3.701915
# 14718 1                0            98                  40.40862 -3.707649
# 14723 2               15            93                  40.40844 -3.698969
# 14725 1                0           100                  40.41112 -3.706749
# 14731 4               20           100                  40.41036 -3.705118
# 14734 1                0            NA                  40.41118 -3.693730
# 14736 2               20            88                  40.41228 -3.696911
# 14737 2               10            91                  40.41232 -3.695173
# 14738 1                0           100                  40.41373 -3.697207
# 14739 2               13            87                  40.41336 -3.694922
# 14743 2               29            94                  40.42679 -3.697220
# 14744 2               15            93                  40.42176 -3.699134
# 14745 1               25            83                  40.42385 -3.698944
# 14746 6               35            97                  40.42510 -3.699414
# 14748 1               15            97                  40.42680 -3.696384
# 14750 1                0            93                  40.42741 -3.699927
# 14751 1                0            95                  40.42449 -3.698675
# 14753 2               10           100                  40.41141 -3.696039
# 14754 1                0            90                  40.41269 -3.695939
# 14758 2               15            98                  40.41875 -3.698898
# 14759 2               10            98                  40.41632 -3.700375
# 14760 1                0            NA                  40.41428 -3.702910
# 14761 1                0            87                  40.41143 -3.697099
# 14763 4               35            93                  40.41352 -3.696828
# 14764 1                0            NA                  40.41267 -3.699217
# 14767 2                9            95                  40.41293 -3.695167

# %% [markdown]
# Crea una nueva columna llamada Square.Meters a partir de Square.Feet. Recuerda que un pie cuadrado son 0.092903 metros cuadrados.

# %%
df_madrid$Square.Meters <- df_madrid$Square.Feet * 0.092903
head(df_madrid)
# Out:
#    Neighbourhood Accommodates Bathrooms Bedrooms Beds Price Square.Feet
# 4  Embajadores    2           1         1         2    50   NA
# 5  Embajadores    5           1         2         4    95   NA
# 6  La Latina      4           1         1         2    69   NA
# 9  Embajadores    4           1         1         2    57   NA
# 10 La Latina      2           1         1         1    59   NA
# 15 La Latina     14           2         3        14   120   NA
#    Guests.Included Extra.People Review.Scores.Rating Latitude Longitude
# 4  1               20           93                   40.41126 -3.697305
# 5  4                0           97                   40.41256 -3.701155
# 6  2               18           91                   40.40791 -3.705095
# 9  2                8           98                   40.41162 -3.703281
# 10 1                0           95                   40.40734 -3.707019
# 15 2               18           92                   40.40908 -3.704744
#    Square.Meters
# 4  NA
# 5  NA
# 6  NA
# 9  NA
# 10 NA
# 15 NA

# %% [markdown]
# ¿Que porcentaje de los apartamentos no muestran los metros cuadrados? Es decir, ¿cuantos tienen NA en Square.Meters?

# %%
print(paste("El número total de entradas del dataframe es:", nrow(df_madrid)))
print(paste("El número de apartamentos que no muestran los metros cuadrados es:", 
            nrow(df_madrid[is.na(df_madrid$Square.Meters),])))
print(paste("Esto equivale al: ",
            round(nrow(df_madrid[is.na(df_madrid$Square.Meters),])/nrow(df_madrid)*100, 2),"%"))
# Out:
# [1] "El número total de entradas del dataframe es: 5601"
# [1] "El número de apartamentos que no muestran los metros cuadrados es: 5254"
# [1] "Esto equivale al:  93.8 %"

# %% [markdown]
# De todos los apartamentos que tienen un valor de metros cuadrados diferente de NA
# ¿Que porcentaje de los apartamentos tienen 0 metros cuadrados?

# %%
n_sm_zero <- nrow(df_madrid[!is.na(df_madrid$Square.Meters) & df_madrid$Square.Meters == 0,])
total_sm <- nrow(df_madrid[!is.na(df_madrid$Square.Meters),])
print(paste("El número total de apartamentos con metros cuadrados diferentes de NA es:", total_sm))
print(paste("El número de apartamentos con 0 metros es:", n_sm_zero))
print(paste("El porcentaje de apartamentos con 0 metros es:", round(n_sm_zero/total_sm*100,2),"%"))
# Out:
# [1] "El número total de apartamentos con metros cuadrados diferentes de NA es: 347"
# [1] "El número de apartamentos con 0 metros es: 128"
# [1] "El porcentaje de apartamentos con 0 metros es: 36.89 %"

# %% [markdown]
# Reemplazar todos los 0m^2 por NA

# %%
df_madrid$Square.Meters[!is.na(df_madrid$Square.Meters) & df_madrid$Square.Meters == 0] <- NA

# %%
print(paste("El número de apartamentos con NA en los metros cuadrados es:", 
            nrow(df_madrid[is.na(df_madrid$Square.Meters),])))
# Out:
# [1] "El número de apartamentos con NA en los metros cuadrados es: 5382"

# %% [markdown]
# Son muchos, vamos a intentar crear un modelo que nos prediga cuantos son los metros cuadrados en función del resto de variables para tratar de rellenar esos NA. Pero **antes de crear el modelo** vamos a hacer:
# * pintar el histograma de los metros cuadrados y ver si tenemos que filtrar algún elemento más.
# * crearemos una variable sintética nueva basada en la similitud entre barrios que usaremos en nuestro modelo.

# %% [markdown]
# Pinta el histograma de los metros cuadrados y ver si tenemos que filtrar algún elemento más

# %% [markdown]
# Asigna el valor NA a la columna Square.Meters de los apartamentos que tengan menos de 20 m^2

# %%
library(ggplot2)
ggplot(data=df_madrid, aes(x=Square.Meters))+
geom_histogram(bins=20, fill="#AEF5EE",color="#70C1B9")+theme_bw()

print("Observamos que hay apartamentos con menos de 20 metros cuadrados, asignaremos un NA")
# Out:
# Warning message:
# “Removed 5382 rows containing non-finite values (stat_bin).”
# [1] "Observamos que hay apartamentos con menos de 20 metros cuadrados, asignaremos un NA"
# plot without title

# %% [markdown]
# //Asignaré el valor NA a los apartamentos que tengan menos de 20 m^2 y > de 400

# %%
df_madrid$Square.Meters[!is.na(df_madrid$Square.Meters) & df_madrid$Square.Meters < 20] <- NA
df_madrid$Square.Meters[!is.na(df_madrid$Square.Meters) & df_madrid$Square.Meters > 400] <- NA

ggplot(data=df_madrid, aes(x=Square.Meters))+
geom_histogram(bins=20, fill="#AEF5EE",color="#70C1B9")+theme_bw()
# Out:
# Warning message:
# “Removed 5428 rows containing non-finite values (stat_bin).”
# plot without title

# %% [markdown]
# Existen varios Barrios que todas sus entradas de Square.Meters son NA, vamos a eliminar del dataset todos los pisos que pertenecen a estos barrios.

# %%
summary(df_madrid[,c(1,13)])
#observamos que tengo 5428 NA´s en Square.Meters
# Out:
#  Neighbourhood      Square.Meters
#  Length:5601        Min.   : 22.02
#  Class :character   1st Qu.: 44.97
#  Mode  :character   Median : 60.02
#                     Mean   : 68.54
#                     3rd Qu.: 79.99
#                     Max.   :200.02
#                     NA's   :5428

# %%
#Conocemos el total de barrios del dataset
print("Nombres de los Barrios del Dataset:")
unique(df_madrid$Neighbourhood)

total_barrios <-length(unique(df_madrid$Neighbourhood))
print(paste("Total Barrios del Dataset: ", total_barrios))
# Out:
# [1] "Nombres de los Barrios del Dataset:"
#  [1] "Embajadores"         "La Latina"           "Palacio"
#  [4] "Malasaña"            "Sol"                 "Acacias"
#  [7] "Palos do Moguer"     "Pacifico"            "El Tréntaiseis"
# [10] "Ibiza"               "Jerónimos"           "Cortes"
# [13] "Justicia"            "Recoletos"           "Goya"
# [16] "Fuente del Berro"    "Guindalera"          "Lista"
# [19] "Hispanoamérica"      "Nueva España"        "Castilla"
# [22] "Cuatro Caminos"      "Castillejos"         "Valdeacederas"
# [25] "Gaztambide"          "Hortaleza"           "Arapiles"
# [28] "Trafalgar"           "Almagro"             "Rios Rosas"
# [31] "Fuencarral-el Pardo" "Argüelles"           "Villaverde"
# [34] "Aluche"              "Tetuán"              "Usera"
# [37] "Puente de Vallecas"  "La Chopera"          "Legazpi"
# [40] "Delicias"            "Ciudad Lineal"       "Moncloa"
# [43] "Adelfas"             "Retiro"              "Castellana"
# [46] "El Viso"             "Ciudad Jardin"       "Bellas Vistas"
# [49] "Berruguete"          "Almenara"            "Carabanchel"
# [52] "Moratalaz"           "San Blas"            "Imperial"
# [55] "Estrella"            "Centro"              "Prosperidad"
# [58] "Villa de Vallecas"   "Barajas"             "Vallehermosa"
# [61] "Chamberí"            "Vicálvaro"           "Atocha"
# [64] "Arganzuela"          "Fuencarral-El Pardo"
# [1] "Total Barrios del Dataset:  65"

# %%
#Removemos del Dataframe los barrios que tengan NA´s en sus metros cuadrados
df_Barrios <-aggregate(Square.Meters~Neighbourhood,df_madrid,mean,na.rm=T)

df_Barrios[order(df_Barrios$Square.Meters, decreasing = T),]

df_Barrios <-droplevels(df_Barrios)
# Out:
#    Neighbourhood    Square.Meters
# 33 Rios Rosas       200.02016
# 17 El Tréntaiseis   164.99573
# 20 Fuente del Berro 158.95703
# 27 Moratalaz        124.95453
# 25 Lista            119.98422
# 9  Castellana       116.68617
# 34 San Blas         102.00749
# 28 Pacifico         100.01008
# 5  Arapiles          97.50170
# 6  Argüelles         83.98431
# 16 Cuatro Caminos    83.00883
# 14 Ciudad Lineal     82.49786
# 10 Castilla          82.00238
# 35 Sol               79.03723
# 21 Goya              77.52755
# 8  Carabanchel       76.64498
# 32 Retiro            74.97272
# 2  Adelfas           69.95596
# 36 Trafalgar         66.67339
# 4  Almenara          65.99829
# 22 Jerónimos         65.03210
# 1  Acacias           64.97016
# 29 Palacio           61.59469
# 26 Malasaña          61.29454
# 12 Chamberí          60.01534
# 13 Ciudad Jardin     60.01534
# 38 Vicálvaro         60.01534
# 23 Justicia          59.98050
# 30 Palos do Moguer   58.20373
# 24 La Latina         58.10154
# 19 Embajadores       52.04426
# 3  Almagro           49.98181
# 37 Usera             49.98181
# 15 Cortes            45.90440
# 18 El Viso           40.04119
# 7  Barajas           36.97539
# 31 Recoletos         30.00767
# 11 Centro            24.99091

# %%
#Comprobamos el número de barrios antes y después de eliminar los NA´s
barrios_with_na <-as.list(unique(df_madrid$Neighbourhood))
print("Total Barrios del Dataset")
length(barrios_with_na)

barrios_without_na<-as.list(unique(df_Barrios$Neighbourhood))
print("Total Barrios del dataset sin NA´s")
length(barrios_without_na)
# Out:
# [1] "Total Barrios del Dataset"
# [1] 65
# [1] "Total Barrios del dataset sin NA´s"
# [1] 38

# %%
#Imprimo los barrios resultantes de la corrección:
barrios_corregidos <- barrios_with_na[barrios_with_na %in% barrios_without_na]
barrios_corregidos
# Out:
# [[1]]
# [1] "Embajadores"
#
# [[2]]
# [1] "La Latina"
#
# [[3]]
# [1] "Palacio"
#
# [[4]]
# [1] "Malasaña"
#
# [[5]]
# [1] "Sol"
#
# [[6]]
# [1] "Acacias"
#
# [[7]]
# [1] "Palos do Moguer"
#
# [[8]]
# [1] "Pacifico"
#
# [[9]]
# [1] "El Tréntaiseis"
#
# [[10]]
# [1] "Jerónimos"
#
# [[11]]
# [1] "Cortes"
#
# [[12]]
# [1] "Justicia"
#
# [[13]]
# [1] "Recoletos"
#
# [[14]]
# [1] "Goya"
#
# [[15]]
# [1] "Fuente del Berro"
#
# [[16]]
# [1] "Lista"
#
# [[17]]
# [1] "Castilla"
#
# [[18]]
# [1] "Cuatro Caminos"
#
# [[19]]
# [1] "Arapiles"
#
# [[20]]
# [1] "Trafalgar"
#
# [[21]]
# [1] "Almagro"
#
# [[22]]
# [1] "Rios Rosas"
#
# [[23]]
# [1] "Argüelles"
#
# [[24]]
# [1] "Usera"
#
# [[25]]
# [1] "Ciudad Lineal"
#
# [[26]]
# [1] "Adelfas"
#
# [[27]]
# [1] "Retiro"
#
# [[28]]
# [1] "Castellana"
#
# [[29]]
# [1] "El Viso"
#
# [[30]]
# [1] "Ciudad Jardin"
#
# [[31]]
# [1] "Almenara"
#
# [[32]]
# [1] "Carabanchel"
#
# [[33]]
# [1] "Moratalaz"
#
# [[34]]
# [1] "San Blas"
#
# [[35]]
# [1] "Centro"
#
# [[36]]
# [1] "Barajas"
#
# [[37]]
# [1] "Chamberí"
#
# [[38]]
# [1] "Vicálvaro"

# %%
#Creamos un nuevo dataframe para diferenciar el antiguo del nuevo que hemos limpiado
new_df_madrid<- df_madrid[df_madrid$Neighbourhood %in% barrios_corregidos,]

# %%
#Limpiamos los Levels del nuevo dataset
new_df_madrid_<-droplevels(new_df_madrid)
summary(new_df_madrid[,c(1,13)])
# Out:
#  Neighbourhood      Square.Meters
#  Length:4901        Min.   : 22.02
#  Class :character   1st Qu.: 44.97
#  Mode  :character   Median : 60.02
#                     Mean   : 68.54
#                     3rd Qu.: 79.99
#                     Max.   :200.02
#                     NA's   :4728

# %%
#En el summary anterior podemos observar que tenemos ahora 4728 registros de NA´s en Square.Meters
#Con unique podemos saber los barrios que nos han quedado luego de eliminar los barrios en los que todos sus pisos
#tenían un NA en los metros cuadrados

unique(new_df_madrid$Neighbourhood)
head(new_df_madrid)
# Out:
#  [1] "Embajadores"      "La Latina"        "Palacio"          "Malasaña"
#  [5] "Sol"              "Acacias"          "Palos do Moguer"  "Pacifico"
#  [9] "El Tréntaiseis"   "Jerónimos"        "Cortes"           "Justicia"
# [13] "Recoletos"        "Goya"             "Fuente del Berro" "Lista"
# [17] "Castilla"         "Cuatro Caminos"   "Arapiles"         "Trafalgar"
# [21] "Almagro"          "Rios Rosas"       "Argüelles"        "Usera"
# [25] "Ciudad Lineal"    "Adelfas"          "Retiro"           "Castellana"
# [29] "El Viso"          "Ciudad Jardin"    "Almenara"         "Carabanchel"
# [33] "Moratalaz"        "San Blas"         "Centro"           "Barajas"
# [37] "Chamberí"         "Vicálvaro"
#    Neighbourhood Accommodates Bathrooms Bedrooms Beds Price Square.Feet
# 4  Embajadores    2           1         1         2    50   NA
# 5  Embajadores    5           1         2         4    95   NA
# 6  La Latina      4           1         1         2    69   NA
# 9  Embajadores    4           1         1         2    57   NA
# 10 La Latina      2           1         1         1    59   NA
# 15 La Latina     14           2         3        14   120   NA
#    Guests.Included Extra.People Review.Scores.Rating Latitude Longitude
# 4  1               20           93                   40.41126 -3.697305
# 5  4                0           97                   40.41256 -3.701155
# 6  2               18           91                   40.40791 -3.705095
# 9  2                8           98                   40.41162 -3.703281
# 10 1                0           95                   40.40734 -3.707019
# 15 2               18           92                   40.40908 -3.704744
#    Square.Meters
# 4  NA
# 5  NA
# 6  NA
# 9  NA
# 10 NA
# 15 NA

# %% [markdown]
# El barrio parece ser un indicador importante para los metros cuadrados de un apartamento.
#
# Vamos a agrupar los barrios por metros cuadrados. Podemos usar una matriz de similaridad de Tukey tal y como hicimos en el curso de estadística:

# %%
tky<-TukeyHSD(aov( formula=Square.Meters~Neighbourhood, data=new_df_madrid ))
tky.result<-data.frame(tky$Neighbourhood)
cn <-sort(unique(new_df_madrid$Neighbourhood))
resm <- matrix(NA, length(cn),length(cn))
rownames(resm) <- cn
colnames(resm) <- cn
resm[lower.tri(resm) ] <- round(tky.result$p.adj,4)
resm[upper.tri(resm) ] <- t(resm)[upper.tri(resm)] 
diag(resm) <- 1
library(ggplot2)
library(reshape2)
dfResm <- melt(resm)
ggplot(dfResm, aes(x=Var1, y=Var2, fill=value))+
  geom_tile(colour = "black")+
  scale_fill_gradient(low = "white",high = "steelblue")+
  ylab("Class")+xlab("Class")+theme_bw()+
  theme(axis.text.x = element_text(angle = 90, hjust = 1),legend.position="none")
# Out:
# plot without title

# %% [markdown]
# Usando como variable de distancia: 1-resm
# Dibuja un dendrograma de los diferentes barrios.

# %%
library(dendextend)

options(repr.plot.height=6,repr.plot.width=10)
d <- as.dist(1 - resm)

hc <- hclust(d,method="complete")
hcd <- as.dendrogram(hc)
par(cex=0.7)
plot(color_branches(hcd,h=0.3))
# Out:
# plot without title

# %%
options(repr.plot.height=6,repr.plot.width=10)
d <- as.dist(1 - resm)

hc <- hclust(d,method="complete")
hcd <- as.dendrogram(hc)
par(cex=0.7)
plot(color_branches(hcd,h=0.3))

ncluster <- rect.hclust(hc, h=0.5)

print(paste("Al realizar el corte en 0.5, aparecen clusters: ", length(ncluster)))
# Out:
# [1] "Al realizar el corte en 0.5, aparecen clusters:  3"
# plot without title

# %%
hcd
# Out:
# 'dendrogram' with 2 branches and 38 members total, at height 0.9985

# %% [markdown]
# ¿Que punto de corte sería el aconsejable?, ¿cuantos clusters aparecen?

# %%
library(cluster)
clusters <- cutree(hcd, h=0.5)
grafica_s <- silhouette(clusters, d)
plot(grafica_s,col=1:max(clusters),border=NA)
summary (grafica_s)
# Out:
# Silhouette of 38 units in 3 clusters from silhouette.default(x = clusters, dist = d) :
#  Cluster sizes and average silhouette widths:
#        22        10         6
# 0.3636192 1.0000000 0.3487327
# Individual silhouette widths:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
# -1.0000  0.0000  1.0000  0.5287  1.0000  1.0000
# Plot with title “Silhouette plot of (x = clusters, dist = d)”

# %% [markdown]
# Vamos a crear una nueva columna en el dataframe df_madrid con un nuevo identificador marcado por los clusters obtenidos. Esta columna la llamaremos neighb_id

# %%
cluster <- as.factor(cutree(hc,h=0.5))
new_df_madrid$neighb_id <- cluster[new_df_madrid$Neighbourhood]

head (new_df_madrid)
# Out:
#    Neighbourhood Accommodates Bathrooms Bedrooms Beds Price Square.Feet
# 4  Embajadores    2           1         1         2    50   NA
# 5  Embajadores    5           1         2         4    95   NA
# 6  La Latina      4           1         1         2    69   NA
# 9  Embajadores    4           1         1         2    57   NA
# 10 La Latina      2           1         1         1    59   NA
# 15 La Latina     14           2         3        14   120   NA
#    Guests.Included Extra.People Review.Scores.Rating Latitude Longitude
# 4  1               20           93                   40.41126 -3.697305
# 5  4                0           97                   40.41256 -3.701155
# 6  2               18           91                   40.40791 -3.705095
# 9  2                8           98                   40.41162 -3.703281
# 10 1                0           95                   40.40734 -3.707019
# 15 2               18           92                   40.40908 -3.704744
#    Square.Meters neighb_id
# 4  NA            2
# 5  NA            2
# 6  NA            2
# 9  NA            2
# 10 NA            2
# 15 NA            2

# %% [markdown]
# Vamos a crear dos grupos, uno test y otro train.
#
# Tratamos de predecir los metros cuadrados en función del resto de columnas del dataframe.

# %%
set.seed(12345)
#Creamos un grupo de entrenamiento del 80%

idx <- sample(1:nrow(new_df_madrid),nrow(new_df_madrid)*0.8)
df_madrid_train <- new_df_madrid[idx,]
df_madrid_test <- new_df_madrid[-idx,]

paste("Número de muestras training:",nrow(df_madrid_train))
paste("Número de muestras testing:",nrow(df_madrid_test))
# Out:
# [1] "Número de muestras training: 3920"
# [1] "Número de muestras testing: 981"

# %%
cor(df_madrid_train[,c("Accommodates","Square.Meters","Bathrooms","Bedrooms","Beds","Price","Guests.Included","Extra.People")], use = "pairwise.complete.obs")
#Observo la correlación de las variables para utilizarlas las más significativas
# Out:
#                 Accommodates Square.Meters Bathrooms Bedrooms  Beds
# Accommodates    1.0000000    0.6300748     0.5859065 0.7493869 0.8338183
# Square.Meters   0.6300748    1.0000000     0.6759885 0.7449839 0.6016626
# Bathrooms       0.5859065    0.6759885     1.0000000 0.6069240 0.5708747
# Bedrooms        0.7493869    0.7449839     0.6069240 1.0000000 0.7366318
# Beds            0.8338183    0.6016626     0.5708747 0.7366318 1.0000000
# Price           0.5521038    0.5313740     0.6366601 0.5626359 0.5329015
# Guests.Included 0.5660629    0.4119604     0.3553145 0.4217499 0.4479799
# Extra.People    0.2193161    0.3200164     0.1314124 0.1351053 0.1522127
#                 Price     Guests.Included Extra.People
# Accommodates    0.5521038 0.5660629       0.2193161
# Square.Meters   0.5313740 0.4119604       0.3200164
# Bathrooms       0.6366601 0.3553145       0.1314124
# Bedrooms        0.5626359 0.4217499       0.1351053
# Beds            0.5329015 0.4479799       0.1522127
# Price           1.0000000 0.3073581       0.1055870
# Guests.Included 0.3073581 1.0000000       0.3264874
# Extra.People    0.1055870 0.3264874       1.0000000

# %%
pairs(df_madrid_train[,c("Bathrooms","Bedrooms","Price","Guests.Included","Extra.People","Review.Scores.Rating","Latitude","Longitude")],pch='.', gap=.5,cex=5)
# Out:
# plot without title

# %%
modelo_1 <- lm (Square.Meters~ Bedrooms + Accommodates ,data=df_madrid_train)
modelo_2 <- lm (Square.Meters~ Price + neighb_id ,data=df_madrid_train)
modelo_3 <- lm (Square.Meters~ Price + Bedrooms + Bathrooms + Accommodates, data=df_madrid_train)
modelo_4 <- lm (Square.Meters~ Price + Bedrooms + Bathrooms, data=df_madrid_train)
modelo_5 <- lm (Square.Meters~ Bathrooms + Bedrooms, data=df_madrid_train)

summary(modelo_1)
summary(modelo_2)
summary(modelo_3)
summary(modelo_4)
summary(modelo_5)
# Out:
# Call:
# lm(formula = Square.Meters ~ Bedrooms + Accommodates, data = df_madrid_train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -39.449 -13.481  -2.938   8.668  98.083
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    22.390      4.383   5.108 1.02e-06 ***
# Bedrooms       21.538      2.857   7.538 5.02e-12 ***
# Accommodates    2.489      1.348   1.847   0.0668 .
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 21.99 on 143 degrees of freedom
#   (3774 observations deleted due to missingness)
# Multiple R-squared:  0.5654,	Adjusted R-squared:  0.5593
# F-statistic: 93.01 on 2 and 143 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = Square.Meters ~ Price + neighb_id, data = df_madrid_train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -73.809 -15.376  -3.508  12.747 101.443
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  57.23839    4.38573  13.051  < 2e-16 ***
# Price         0.20773    0.03266   6.360 2.59e-09 ***
# neighb_id2  -19.28901    4.35098  -4.433 1.84e-05 ***
# neighb_id3   15.87833   11.72639   1.354    0.178
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 25.49 on 142 degrees of freedom
#   (3774 observations deleted due to missingness)
# Multiple R-squared:  0.3884,	Adjusted R-squared:  0.3755
# F-statistic: 30.06 on 3 and 142 DF,  p-value: 4.142e-15
# Call:
# lm(formula = Square.Meters ~ Price + Bedrooms + Bathrooms + Accommodates,
#     data = df_madrid_train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -47.705 -10.934  -2.276   7.701  90.550
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  13.25426    4.61581   2.871  0.00473 **
# Price         0.08012    0.02778   2.884  0.00455 **
# Bedrooms     15.86033    2.84091   5.583 1.21e-07 ***
# Bathrooms    13.98038    4.52166   3.092  0.00241 **
# Accommodates  0.78835    1.31579   0.599  0.55006
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 20.08 on 138 degrees of freedom
#   (3777 observations deleted due to missingness)
# Multiple R-squared:  0.6275,	Adjusted R-squared:  0.6167
# F-statistic: 58.12 on 4 and 138 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = Square.Meters ~ Price + Bedrooms + Bathrooms, data = df_madrid_train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -46.208 -11.620  -1.871   7.729  89.721
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 14.15555    4.35374   3.251 0.001441 **
# Price        0.08088    0.02768   2.921 0.004070 **
# Bedrooms    16.78700    2.37748   7.061 7.23e-11 ***
# Bathrooms   14.84433    4.27568   3.472 0.000689 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 20.04 on 139 degrees of freedom
#   (3777 observations deleted due to missingness)
# Multiple R-squared:  0.6265,	Adjusted R-squared:  0.6185
# F-statistic: 77.73 on 3 and 139 DF,  p-value: < 2.2e-16
# Call:
# lm(formula = Square.Meters ~ Bathrooms + Bedrooms, data = df_madrid_train)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -52.192 -11.266  -1.326   8.708  92.479
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)   13.379      4.399   3.041  0.00281 **
# Bathrooms     19.624      4.190   4.684 6.56e-06 ***
# Bedrooms      18.305      2.372   7.717 1.97e-12 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 20.76 on 141 degrees of freedom
#   (3776 observations deleted due to missingness)
# Multiple R-squared:  0.6178,	Adjusted R-squared:  0.6124
# F-statistic:   114 on 2 and 141 DF,  p-value: < 2.2e-16

# %%
# El modelo 3 es el que tiene el valor R-squared más alto.

df_madrid_train$SMest = predict(modelo_3, df_madrid_train)
df_madrid_test$SMest = predict(modelo_3, df_madrid_test)

#Observamos el histograma de residuos sobre el conjunto de train
hist(df_madrid_train$Square.Meters-df_madrid_train$SMest, main="Histograma de Residuos Train")
plot(df_madrid_train$Square.Meters ,(df_madrid_train$Square.Meters-df_madrid_train$SMest))
# Out:
# Plot with title “Histograma de Residuos Train”
# plot without title

# %% [markdown]
# Mirad el histograma de los residuos sobre el conjunto de test para evaluar la calidad de vuestro modelo

# %%
#Observamos el histograma de residuos sobre el conjunto de test
df_madrid_test$pret_m<-predict(modelo_3,df_madrid_test)
hist(df_madrid_test$Square.Meters-df_madrid_test$pret_m,20, main="Histograma de Residuos Test")
qqnorm(df_madrid_test$Square.Meters-predict(modelo_3,df_madrid_test))
qqline(df_madrid_test$Square.Meters-predict(modelo_3,df_madrid_test), col = 'orange', lwd =2)
# Out:
# Plot with title “Histograma de Residuos Test”
# Plot with title “Normal Q-Q Plot”

# %%
#Mediante la distancia de cooks veremos si hay outliers que afecten el resultado del modelo
plot(cooks.distance(modelo_3))
print("Existen unos valores que podrían considerarse outliers y estarían afectando al resultado del modelo")
# Out:
# [1] "Existen unos valores que podrían considerarse outliers y estarían afectando al resultado del modelo"
# plot without title

# %% [markdown]
# Si tuvieramos un anuncio de un apartamento para 6 personas (Accommodates), con 1 baño, con un precio de 80€/noche y 3 habitaciones en el barrio de Sol, con 3 camas y un review de 80.
# ¿Cuantos metros cuadrados tendría? Si tu modelo necesita algúna variable adicional puedes inventartela dentro del rango de valores del dataset.
# ¿Como varía sus metros cuadrados con cada habitación adicional?

# %%
df_new_apartment <- data.frame(
    "Accommodates" = 6,
    "Price" = 80,
    "Bedrooms" = 3,
    "Neighbourhood" = "Sol",
    "Bathrooms" = 2,
    "Beds" = 4,
    "neighb_id" = as.factor(6)
)

# %%
predict_meters_apto <- predict(modelo_3, df_new_apartment, na.action = na.pass)
paste("Los metros cuadrados que se predicen que tendría el apartamento son:", round(predict_meters_apto,2))
# Out:
# [1] "Los metros cuadrados que se predicen que tendría el apartamento son: 99.94"

# %%
paste("Por cada habitación adicional se predice que los metros cuadrados aumentan:",round(modelo_3$coefficients["Bedrooms"],2))
# Out:
# [1] "Por cada habitación adicional se predice que los metros cuadrados aumentan: 15.86"

# %% [markdown]
# Rellenar los Square.Meters con valor NA con el estimado con el modelo anterior.

# %%
new_df_madrid$Square.Meters =  predict (modelo_3, new_df_madrid)
head(new_df_madrid)
# Out:
#    Neighbourhood Accommodates Bathrooms Bedrooms Beds Price Square.Feet
# 4  Embajadores    2           1         1         2    50   NA
# 5  Embajadores    5           1         2         4    95   NA
# 6  La Latina      4           1         1         2    69   NA
# 9  Embajadores    4           1         1         2    57   NA
# 10 La Latina      2           1         1         1    59   NA
# 15 La Latina     14           2         3        14   120   NA
#    Guests.Included Extra.People Review.Scores.Rating Latitude Longitude
# 4  1               20           93                   40.41126 -3.697305
# 5  4                0           97                   40.41256 -3.701155
# 6  2               18           91                   40.40791 -3.705095
# 9  2                8           98                   40.41162 -3.703281
# 10 1                0           95                   40.40734 -3.707019
# 15 2               18           92                   40.40908 -3.704744
#    Square.Meters neighb_id
# 4   48.67778     2
# 5   70.50865     2
# 6   51.77680     2
# 9   50.81534     2
# 10  49.39888     2
# 15 109.44758     2

# %% [markdown]
# Usar PCA para encontrar el apartamento más cercano a uno dado.
#
# Este algoritmo nos ayudaría a dado un apartamento que el algoritmo nos devolvería los 5 apartamentos más similares.
#
#
# Crearemos una función tal que le pasemos un apartamento con los siguientes datos:
# * Accommodates
# * Bathrooms
# * Bedrooms
# * Beds
# * Price
# * Guests.Included
# * Extra.People
# * Review.Scores.Rating
# * Latitude
# * Longitude
# * Square.Meters
#
# y nos devuelva los 5 más similares de:

# %%
#Generamos el dataframe con los datos del piso que inventaremos
Accommodates_piso <- 6
Bathrooms_piso <- 2
Bedrooms_piso <- 3
Beds_piso <- 5
Price_piso <- 110
Guests.Included_piso <- 2
Extra.People_piso <-2
Review.Scores.Rating_piso <- 90
Latitude_piso <- 40.47152
Longitude_piso <- -3.715909
Square.Meters_piso <- 120

df_apto_new <- data.frame(Accommodates=Accommodates_piso, 
                          Bathrooms=Bathrooms_piso, 
                          Bedrooms=Bedrooms_piso, 
                          Beds=Beds_piso, 
                          Price=Price_piso, 
                          Guests.Included=Guests.Included_piso, 
                          Extra.People=Extra.People_piso, 
                          Review.Scores.Rating=Review.Scores.Rating_piso, 
                          Latitude=Latitude_piso, 
                          Longitude=Longitude_piso, 
                          Square.Meters=Square.Meters_piso)

df_madrid_aptos <- na.omit(new_df_madrid[,c('Accommodates'
                                            ,'Bathrooms'
                                            ,'Bedrooms'
                                            ,'Beds'
                                            ,'Price'
                                            ,'Guests.Included'
                                            ,'Extra.People'
                                            ,'Review.Scores.Rating'
                                            ,'Latitude'
                                            ,'Longitude'
                                            ,'Square.Meters')])

# %%
#Aplicamos PCA sobre el dataframe de los apartamentos de Madrid
pr_aptos <- prcomp(df_madrid_aptos, center=TRUE, scale.=TRUE)
str(pr_aptos)
# Out:
# List of 5
#  $ sdev    : num [1:11] 2.233 1.176 1.037 1.004 0.823 ...
#  $ rotation: num [1:11, 1:11] 0.399 0.357 0.397 0.382 0.345 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:11] "Accommodates" "Bathrooms" "Bedrooms" "Beds" ...
#   .. ..$ : chr [1:11] "PC1" "PC2" "PC3" "PC4" ...
#  $ center  : Named num [1:11] 4.13 1.24 1.42 2.38 87.17 ...
#   ..- attr(*, "names")= chr [1:11] "Accommodates" "Bathrooms" "Bedrooms" "Beds" ...
#  $ scale   : Named num [1:11] 1.9 0.504 0.946 1.524 54.23 ...
#   ..- attr(*, "names")= chr [1:11] "Accommodates" "Bathrooms" "Bedrooms" "Beds" ...
#  $ x       : num [1:4187, 1:11] -1.493 1.195 -0.724 -0.894 -1.923 ...
#   ..- attr(*, "dimnames")=List of 2
#   .. ..$ : chr [1:4187] "4" "5" "6" "9" ...
#   .. ..$ : chr [1:11] "PC1" "PC2" "PC3" "PC4" ...
#  - attr(*, "class")= chr "prcomp"

# %%
varianza = pr_aptos$sdev^2/sum(pr_aptos$sdev^2)
plot(cumsum(varianza),main="Autovalores")
n = 5
paste("La suma de las varianza de los", n, "primeras componentes, es: " ,round(sum(varianza[1:n]*100), 1))
pca_var = round(varianza*100, 1)
barplot (pca_var)
# Out:
# [1] "La suma de las varianza de los 5 primeras componentes, es:  83"
# Plot with title “Autovalores”
# plot without title

# %%
library("FactoMineR")
res.pca <- PCA(df_madrid_aptos)
head(res.pca$eig)
# Out:
#        eigenvalue percentage of variance cumulative percentage of variance
# comp 1 4.9847439  45.315854              45.31585
# comp 2 1.3826970  12.569973              57.88583
# comp 3 1.0744110   9.767372              67.65320
# comp 4 1.0075890   9.159900              76.81310
# comp 5 0.6771948   6.156316              82.96942
# comp 6 0.5978753   5.435230              88.40465

# %%
plot(res.pca, choix = "ind", autoLab = "yes")
# Out:
# Warning message:
# “ggrepel: 4173 unlabeled data points (too many overlaps). Consider increasing max.overlaps”
# plot without title

# %%
plot(res.pca, choix = "var", autoLab = "yes")
# Out:
# plot without title

# %%
pr_aptos$rotation[rownames(pr_aptos$rotation) 
                  %in% c('Accommodates'
                                 ,'Bathrooms'
                                 ,'Bedrooms'
                                 ,'Beds'
                                 ,'Price'
                                 ,'Guests.Included'
                                 ,'Extra.People'
                                 ,'Review.Scores.Rating'
                                 ,'Latitude'
                                 ,'Longitude'
                                 ,'Square.Meters')
                  ,1:5]
# Out:
#                      PC1        PC2         PC3          PC4
# Accommodates         0.39895352  0.06419696  0.002122795 -0.142567723
# Bathrooms            0.35672858 -0.07149226 -0.155889725  0.164764932
# Bedrooms             0.39728438 -0.01412458 -0.123833601 -0.001907358
# Beds                 0.38190749  0.04068383 -0.060967640 -0.090244261
# Price                0.34529758 -0.02957072 -0.132714398  0.169949200
# Guests.Included      0.28930533  0.09827266  0.388588990 -0.197939404
# Extra.People         0.13231541  0.14040181  0.786506590 -0.214625521
# Review.Scores.Rating 0.03257343  0.11580934  0.322035223  0.907499736
# Latitude             0.01757202 -0.69344874  0.134640807 -0.009737271
# Longitude            0.03703896 -0.68077285  0.163674556  0.044938709
# Square.Meters        0.43210593 -0.03055634 -0.144259319  0.067693211
#                      PC5
# Accommodates          0.17603200
# Bathrooms            -0.27192698
# Bedrooms              0.14350441
# Beds                  0.24093775
# Price                -0.40692923
# Guests.Included       0.21429772
# Extra.People         -0.28364932
# Review.Scores.Rating  0.12928269
# Latitude             -0.46115294
# Longitude             0.54074238
# Square.Meters        -0.05170815

# %%
num_componentes_pca <- 11
aptos_similares <- function(pr_aptos,df_apto_new){
    
    pca <- predict(pr_aptos, df_apto_new)
    pca <- matrix(pca[,1:num_componentes_pca],nrow=1)
    df_comp <- pr_aptos$x[,1:num_componentes_pca]
    dist <- rep(NA,nrow(df_comp))
    for (i in 1:nrow(df_comp)){
        dist[i]<-sum((pca-df_comp[i,])^10)
    }

    indices_similares_5 <- sort.list(dist) 
    
    #Ordeno la lista de forma ascendente para quedarme con los 5 primeros aptos
    print("A continuación los 5 apartamentos similares:")
    df_madrid_aptos[indices_similares_5 %in% 1:5,]
}



aptos_similares(pr_aptos, df_apto_new)
# Out:
# [1] "A continuación los 5 apartamentos similares:"
#       Accommodates Bathrooms Bedrooms Beds Price Guests.Included Extra.People
# 4039  4            1         2        3     83   2               20
# 6927  3            1         1        1     81   2               11
# 7345  6            2         2        4    115   2               10
# 10661 2            1         1        1     45   1                0
# 12373 2            1         1        1     60   1                0
#       Review.Scores.Rating Latitude Longitude Square.Meters
# 4039   80                  40.40727 -3.700791 68.75884
# 6927   80                  40.42342 -3.704541 51.94991
# 7345   88                  40.42465 -3.705533 86.87983
# 10661 100                  40.40491 -3.694595 48.27717
# 12373  96                  40.42794 -3.703501 49.47900

# %% [markdown]
# Bonus: ¿de todas las coordenadas PCA cual es la que mejor permite clasificar por id de barrio?
#
# ¿Por qué?
